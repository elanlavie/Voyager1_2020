# %%
# %matplotlib inline
import pylab as plt
from blimpy import Waterfall
import turbo_seti.find_doppler.seti_event as turbo
import turbo_seti.find_event as find

# %%
#Plotting spectrum for first ON observation
file_path = '/mnt_blpd14/datax2/voyager_2020/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_80036_DIAG_VOYAGER-1_0011.rawspec.0000.h5'
f_start = 8419.51
f_stop = 8419.58
obs = Waterfall(file_path, f_start, f_stop)

obs.plot_spectrum(f_start=f_start, f_stop=f_stop)
# Out:
# extracting integration 0...

# %%
print(obs)
# Out:
# Waterfall data: /mnt_blpd14/datax2/voyager_2020/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_80036_DIAG_VOYAGER-1_0011.rawspec.0000.h5

# %%
#Run turboSETI
"""max_drift_rate = 5
signal_to_noise = 20

find_seti_event = turbo.FindDoppler(file, max_drift=max_drift_rate, snr=signal_to_noise)
find_seti_event.search()"""

# %%
from turbo_seti.find_event.find_event import make_table

df = make_table('/datax/scratch/elavie/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_80036_DIAG_VOYAGER-1_0011.rawspec.0000.dat')

df = df.set_index('TopHitNum')
df.sort_values('DriftRate')
# Out:
#            DriftRate           SNR          Freq  ChanIndx     FreqStart  \
# TopHitNum
# 939        -0.363527  2.232922e+01   8419.565390    651879   8419.566616
# 941        -0.363527  2.257255e+01   8419.520396    667983   8419.521622
# 940        -0.353960  1.928962e+02   8419.542731    659989   8419.543957
# 403        -0.019133  4.408896e+01   9950.030870    233619   9950.032096
# 145        -0.019133  1.237444e+06  10700.030870    233619  10700.032096
# ...              ...           ...           ...       ...           ...
# 431         0.009566  7.348675e+01   9874.989317    877637   9874.990543
# 530         0.009566  1.818248e+01   9591.670473    569529   9591.671700
# 823         0.009566  1.186481e+02   8749.989317    877637   8749.990543
# 283         0.019133  1.301899e+02  10299.969130    814957  10299.970357
# 19          0.019133  8.421701e+01  11049.969130    814957  11049.970357
#
#                 FreqEnd  CoarseChanNum  FullNumHitsInRange  \
# TopHitNum
# 939         8419.564169            915               27069
# 941         8419.519175            915               27069
# 940         8419.541510            915               27069
# 403         9950.029649            393                9870
# 145        10700.029649            137              288047
# ...                 ...            ...                 ...
# 431         9874.988096            418               10097
# 530         9591.669252            515                9828
# 823         8749.988096            802               23086
# 283        10299.967909            273               13985
# 19         11049.967909             17               10065
#
#                                                       FileID     Source  \
# TopHitNum
# 939        spliced_blc00010203040506o7o0111213141516o7o02...  VOYAGER-1
# 941        spliced_blc00010203040506o7o0111213141516o7o02...  VOYAGER-1
# 940        spliced_blc00010203040506o7o0111213141516o7o02...  VOYAGER-1
# 403        spliced_blc00010203040506o7o0111213141516o7o02...  VOYAGER-1
# 145        spliced_blc00010203040506o7o0111213141516o7o02...  VOYAGER-1
# ...                                                      ...        ...
# 431        spliced_blc00010203040506o7o0111213141516o7o02...  VOYAGER-1
# 530        spliced_blc00010203040506o7o0111213141516o7o02...  VOYAGER-1
# 823        spliced_blc00010203040506o7o0111213141516o7o02...  VOYAGER-1
# 283        spliced_blc00010203040506o7o0111213141516o7o02...  VOYAGER-1
# 19         spliced_blc00010203040506o7o0111213141516o7o02...  VOYAGER-1
#
#                           MJD             RA            DEC     DELTAT  \
# TopHitNum
# 939        59046.926342592589  17h12m40.481s  12d24m13.614s  18.253611
# 941        59046.926342592589  17h12m40.481s  12d24m13.614s  18.253611
# 940        59046.926342592589  17h12m40.481s  12d24m13.614s  18.253611
# 403        59046.926342592589  17h12m40.481s  12d24m13.614s  18.253611
# 145        59046.926342592589  17h12m40.481s  12d24m13.614s  18.253611
# ...                       ...            ...            ...        ...
# 431        59046.926342592589  17h12m40.481s  12d24m13.614s  18.253611
# 530        59046.926342592589  17h12m40.481s  12d24m13.614s  18.253611
# 823        59046.926342592589  17h12m40.481s  12d24m13.614s  18.253611
# 283        59046.926342592589  17h12m40.481s  12d24m13.614s  18.253611
# 19         59046.926342592589  17h12m40.481s  12d24m13.614s  18.253611
#
#               DELTAF Hit_ID status in_n_ons RFI_in_range
# TopHitNum
# 939        -2.793968
# 941        -2.793968
# 940        -2.793968
# 403        -2.793968
# 145        -2.793968
# ...              ...    ...    ...      ...          ...
# 431        -2.793968
# 530        -2.793968
# 823        -2.793968
# 283        -2.793968
# 19         -2.793968
#
# [1196 rows x 19 columns]

# %%
from turbo_seti.find_event.find_event_pipeline import find_event_pipeline #PLEASE EXPLAIN THE FROM...

find_event_pipeline('/home/elavie/dat_files.lst', filter_threshold = 3, number_in_cadence = 6)
# Out:
# ************   BEGINNING FIND_EVENT PIPELINE   **************
#
# Assuming the first observation is an ON
# There are 6 total files in the filelist /home/elavie/dat_files.lst
# therefore, looking for events in 1 on-off set(s)
# with a minimum SNR of 10
# Present in all A sources with RFI rejection from the off-sources
# not including signals with zero drift
# saving the output files
#
# ***       DIAG       ***
#
# ------   o   -------
# Loading data...
# Loaded 1196 hits from /datax/scratch/elavie/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_80036_DIAG_VOYAGER-1_0011.rawspec.0000.dat
# Loaded 1145 hits from /datax/scratch/elavie/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_80354_DIAG_VOYAGER-1_0012.rawspec.0000.dat
# Loaded 1137 hits from /datax/scratch/elavie/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_80672_DIAG_VOYAGER-1_0013.rawspec.0000.dat
# Loaded 1143 hits from /datax/scratch/elavie/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_80989_DIAG_VOYAGER-1_0014.rawspec.0000.dat
# Loaded 1145 hits from /datax/scratch/elavie/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_81310_DIAG_VOYAGER-1_0015.rawspec.0000.dat
# Loaded 1142 hits from /datax/scratch/elavie/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_81628_DIAG_VOYAGER-1_0016.rawspec.0000.dat
# All data loaded!
#
# Finding events in this cadence...
# Found a total of 20 hits above the SNR cut in this cadence!
# Found a total of 8 hits in only the on observations in this cadence!
# NOTE: At least one of the on tables is empty - no events across this cadence :(
# Search time: 0.21 sec
# ------   o   -------
# ************  ENDING FIND_EVENT PIPELINE   **************
# Sorry, no events to save :(
# []

# %%
from turbo_seti.find_event.find_event_pipeline import find_event_pipeline #PLEASE EXPLAIN THE FROM...

find_event_pipeline('/home/elavie/dat_files.lst', filter_threshold = 2, number_in_cadence = 6)
# Out:
# ************   BEGINNING FIND_EVENT PIPELINE   **************
#
# Assuming the first observation is an ON
# There are 6 total files in the filelist /home/elavie/dat_files.lst
# therefore, looking for events in 1 on-off set(s)
# with a minimum SNR of 10
# Present in at least one A source with RFI rejection from the off-sources
# not including signals with zero drift
# saving the output files
#
# ***       DIAG       ***
#
# ------   o   -------
# Loading data...
# Loaded 1196 hits from /datax/scratch/elavie/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_80036_DIAG_VOYAGER-1_0011.rawspec.0000.dat
# Loaded 1145 hits from /datax/scratch/elavie/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_80354_DIAG_VOYAGER-1_0012.rawspec.0000.dat
# Loaded 1137 hits from /datax/scratch/elavie/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_80672_DIAG_VOYAGER-1_0013.rawspec.0000.dat
# Loaded 1143 hits from /datax/scratch/elavie/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_80989_DIAG_VOYAGER-1_0014.rawspec.0000.dat
# Loaded 1145 hits from /datax/scratch/elavie/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_81310_DIAG_VOYAGER-1_0015.rawspec.0000.dat
# Loaded 1142 hits from /datax/scratch/elavie/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_81628_DIAG_VOYAGER-1_0016.rawspec.0000.dat
# All data loaded!
#
# Finding events in this cadence...
# Found a total of 20 hits above the SNR cut in this cadence!
# Found a total of 8 hits in only the on observations in this cadence!
# Filter level is 2 - returning this table...
# Search time: 0.25 sec
# ------   o   -------
# ************  ENDING FIND_EVENT PIPELINE   **************
#       TopHitNum  DriftRate         SNR         Freq  ChanIndx    FreqStart  \
# 938         939  -0.363527   22.329223  8419.565390    651879  8419.566616
# 939         940  -0.353960  192.896198  8419.542731    659989  8419.543957
# 940         941  -0.363527   22.572551  8419.520396    667983  8419.521622
# 2120        925  -0.382660   82.805017  8419.542493    660074  8419.542904
# 2790        458   0.487891   30.511767  9791.418716    380016  9791.419127
# 2853        521  -0.688787   27.674567  9610.975066   1000178  9610.975477
# 2854        522   0.918383   27.710133  9610.974655   1000325  9610.975066
# 3265        933  -0.430492  145.127964  8419.542236    660166  8419.542647
#
#           FreqEnd  CoarseChanNum  FullNumHitsInRange  \
# 938   8419.564169            915               27069
# 939   8419.541510            915               27069
# 940   8419.519175            915               27069
# 2120  8419.542088            915                3205
# 2790  9791.418311            447                3746
# 2853  9610.974661            508                3648
# 2854  9610.974250            508                3648
# 3265  8419.541831            915                3424
#
#                                                  FileID  ...  \
# 938   spliced_blc00010203040506o7o0111213141516o7o02...  ...
# 939   spliced_blc00010203040506o7o0111213141516o7o02...  ...
# 940   spliced_blc00010203040506o7o0111213141516o7o02...  ...
# 2120  spliced_blc00010203040506o7o0111213141516o7o02...  ...
# 2790  spliced_blc00010203040506o7o0111213141516o7o02...  ...
# 2853  spliced_blc00010203040506o7o0111213141516o7o02...  ...
# 2854  spliced_blc00010203040506o7o0111213141516o7o02...  ...
# 3265  spliced_blc00010203040506o7o0111213141516o7o02...  ...
#
#                      MJD             RA            DEC     DELTAT     DELTAF  \
# 938   59046.926342592589  17h12m40.481s  12d24m13.614s  18.253611  -2.793968
# 939   59046.926342592589  17h12m40.481s  12d24m13.614s  18.253611  -2.793968
# 940   59046.926342592589  17h12m40.481s  12d24m13.614s  18.253611  -2.793968
# 2120  59046.933703703704  17h12m40.482s  12d24m13.656s  18.253611  -2.793968
# 2790  59046.941087962965  17h12m40.477s  12d24m13.608s  18.253611  -2.793968
# 2853  59046.941087962965  17h12m40.477s  12d24m13.608s  18.253611  -2.793968
# 2854  59046.941087962965  17h12m40.477s  12d24m13.608s  18.253611  -2.793968
# 3265  59046.941087962965  17h12m40.477s  12d24m13.608s  18.253611  -2.793968
#
#      Hit_ID      status in_n_ons RFI_in_range  delta_t
# 938          on_table_1                     0      0.0
# 939          on_table_1                     0      0.0
# 940          on_table_1                     0      0.0
# 2120         on_table_1                     0    636.0
# 2790         on_table_1                     0   1274.0
# 2853         on_table_1                     0   1274.0
# 2854         on_table_1                     0   1274.0
# 3265         on_table_1                     0   1274.0
#
# [8 rows x 21 columns]

# %%
# So with filter level 3 we got no hits but with level 2 we got 8 hits.
# Note that filter level 2 means that there were no events at those frequencies
# in the OFF and 1-2 in the ON. Level 3 means there were no events in the OFF and
# events in all three of the ON. All filter levels include only non-zero drift rates.
#
# The next step is to take a look at the spectrum plots to see whether we
# actually got signals in all three ONs and no signals in all three OFFS... In other words, 
# is this a problem with our data or with our data analysis?b

# %%
#Plotting spectrum for first OFF observation:

file_path = '/mnt_blpd14/datax2/voyager_2020/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_80354_DIAG_VOYAGER-1_0012.rawspec.0000.h5'
f_start = 8419.51
f_stop = 8419.58
obs = Waterfall(file_path, f_start, f_stop)

obs.plot_spectrum(f_start=f_start, f_stop=f_stop)
# Out:
# extracting integration 0...

# %%
#Plotting spectrum for second ON observation:

file_path = '/mnt_blpd14/datax2/voyager_2020/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_80672_DIAG_VOYAGER-1_0013.rawspec.0000.h5'
f_start = 8419.51
f_stop = 8419.58
obs = Waterfall(file_path, f_start, f_stop)

obs.plot_spectrum(f_start=f_start, f_stop=f_stop)
# Out:
# extracting integration 0...

# %%
#Plotting spectrum for second OFF observation:

file_path = '/mnt_blpd14/datax2/voyager_2020/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_80989_DIAG_VOYAGER-1_0014.rawspec.0000.h5'
f_start = 8419.51
f_stop = 8419.58
obs = Waterfall(file_path, f_start, f_stop)

obs.plot_spectrum(f_start=f_start, f_stop=f_stop)
# Out:
# extracting integration 0...

# %%
#Plotting spectrum for third ON observation:

file_path = '/mnt_blpd14/datax2/voyager_2020/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_81310_DIAG_VOYAGER-1_0015.rawspec.0000.h5'
f_start = 8419.51
f_stop = 8419.58
obs = Waterfall(file_path, f_start, f_stop)

obs.plot_spectrum(f_start=f_start, f_stop=f_stop)
# Out:
# extracting integration 0...

# %%
#Plotting spectrum for third OFF observation:

file_path = '/mnt_blpd14/datax2/voyager_2020/spliced_blc00010203040506o7o0111213141516o7o021222324252627_guppi_59046_81628_DIAG_VOYAGER-1_0016.rawspec.0000.h5'
f_start = 8419.51
f_stop = 8419.58
obs = Waterfall(file_path, f_start, f_stop)

obs.plot_spectrum(f_start=f_start, f_stop=f_stop)
# Out:
# extracting integration 0...
